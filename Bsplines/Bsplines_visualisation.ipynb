# %%
import numpy as np
import matplotlib.pyplot as plt
from Bsplines_plot import Bsplines_plots

# %%
knots1 = [0,1/4,2/4,3/4,1]
x_list1 = np.linspace(0,0.99999,1000)

plots1 = Bsplines_plots(x_list1, knots1, spline_degree=3)
plots1.plot_bases('example1')

# %%
knots2 = [0,1,2,3,4,5]
x_list2 = np.linspace(0,4.99999,1000)

plots2 = Bspline_plots(x_list2, knots2, spline_degree=2)
plots2.plot_bases('example2')
